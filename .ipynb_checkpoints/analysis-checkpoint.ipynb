# %%
# !pip install tqdm
# !pip install imagesize
# !pip install matplotlib
# Out:
# Requirement already satisfied: tqdm in /Users/arinasokolova/opt/anaconda3/lib/python3.9/site-packages (4.64.0)
# Requirement already satisfied: imagesize in /Users/arinasokolova/opt/anaconda3/lib/python3.9/site-packages (1.3.0)
# Requirement already satisfied: matplotlib in /Users/arinasokolova/opt/anaconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: numpy>=1.17 in /Users/arinasokolova/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /Users/arinasokolova/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/arinasokolova/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/arinasokolova/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/arinasokolova/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/arinasokolova/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/arinasokolova/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/arinasokolova/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: six>=1.5 in /Users/arinasokolova/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import os
import imagesize
from tqdm import tqdm
import json
import matplotlib.pyplot as plt
# %matplotlib inline

sizes = set()
ratios = set()

DATA_SIZE = 72219

for i in tqdm(range(DATA_SIZE), colour="blue"):
    path = f'./combined/{i}.jpg'
    if os.path.isfile(path):
        height, width = imagesize.get(path)
        sizes.add((height, width))
        ratios.add(height / width)

print('Размеры изображений:', sizes)
print('Соотношения сторон:', ratios)
# Out:
# 100%|███████████████████████████████████| 72219/72219 [00:11<00:00, 6158.08it/s]
# Размеры изображений: {(1920, 1080), (540, 960), (960, 540), (1080, 1920)}
# Соотношения сторон: {0.5625, 1.7777777777777777}

# %%
import json
import matplotlib.pyplot as plt
# %matplotlib inline

def get_depth(cur_node):
    if cur_node is None:
        return 0
    max_size = 0
    children = cur_node.get('children', [])
    for i in range(len(children)):
        max_size = max(max_size, get_depth(children[i]))
    return max_size + 1

def is_clickable(cur_node):
    if cur_node is None:
        return False
    if cur_node.get('clickable', False):
        return True
    flag = False
    children = cur_node.get('children', [])
    for i in range(len(children)):
        flag = flag or is_clickable(children[i])
    return flag
        
depth_count = dict()
unclickable_count = 0
for i in tqdm(range(DATA_SIZE)):
    path = f'./combined/{i}.json'
    if os.path.isfile(path):
        with open(path) as json_file:
            data = json.load(json_file)
            depth = get_depth(data['activity']['root'])
            if depth in depth_count:
                depth_count[depth] += 1
            else:
                depth_count[depth] = 1
            if not is_clickable(data['activity']['root']):
                unclickable_count += 1
#print(values)
#print(keys)
print('Количество неинтерактивных экранов:', unclickable_count)
# Out:
# 100%|███████████████████████████████████| 72219/72219 [01:10<00:00, 1024.17it/s]
# Количество неинтерактивных экранов: 592

# %%
depth_count = dict(sorted(depth_count.items()))
keys = list(depth_count.keys())
values = list(depth_count.values())

print(depth_count)
fig, ax = plt.subplots()
plt.bar(keys, values, width=1)
ax.set_title('Распределение глубин UI-деревьев')
ax.set_xlabel('Глубина')
ax.set_ylabel('Количество деревьев')
fig.set_facecolor('floralwhite')
fig.set_figwidth(12)
fig.set_figheight(8)
plt.show()

fig, ax = plt.subplots()
ax.plot(keys, values,
        linestyle = '-',
        linewidth = 2,
        color = 'crimson')
ax.set_title('Распределение глубин UI-деревьев')
ax.set_xlabel('Глубина')
ax.set_ylabel('Количество деревьев')
fig.set_facecolor('floralwhite')
fig.set_figwidth(12)
fig.set_figheight(8)
plt.show()
# Out:
# {2: 3, 3: 38, 4: 483, 5: 1821, 6: 3076, 7: 3946, 8: 4740, 9: 5931, 10: 5623, 11: 4960, 12: 6415, 13: 5035, 14: 4561, 15: 4200, 16: 3625, 17: 2786, 18: 3010, 19: 1877, 20: 1654, 21: 936, 22: 594, 23: 456, 24: 186, 25: 157, 26: 60, 27: 72, 28: 7, 29: 3, 30: 4, 31: 2}
